# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import keras

# %%
resim =Image.open('/Users/birkankalyon/Desktop/RUZ.jpg')
print(type(resim))
resim_dizi=np.asarray(resim)
print(type(resim_dizi))
print(resim_dizi.shape)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'numpy.ndarray'>
# (640, 427, 3)

# %%
plt.imshow(resim_dizi)

# %%
resim_dizi.shape
# Out:
# (640, 427, 3)

# %%
resim_kirmizi=resim_dizi.copy()

# %%
plt.imshow(resim_kirmizi)

# %% [raw]
# resim_kirmizi.shape

# %%
plt.imshow(resim_kirmizi[:,:,0])

# %%
resim_kirmizi[:,:,0]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [117, 118, 118, ..., 151, 153, 156],
#        [118, 118, 118, ..., 152, 154, 157],
#        [119, 118, 119, ..., 155, 157, 158]], dtype=uint8)

# %%
plt.imshow(resim_kirmizi[:,:,0],cmap='gray')

# %%
plt.imshow(resim_kirmizi[:,:,1],cmap='gray')

# %%
plt.imshow(resim_kirmizi[:,:,2],cmap='gray')

# %%
resim_kirmizi[:,:,2]=0

# %%
plt.imshow(resim_kirmizi)
